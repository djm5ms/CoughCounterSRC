# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data_df = pd.read_csv('Lab8OverDampedREDLED.csv')
data_df.head()
# Out:
#     Time (s)  Channel 1 (V)
# 0 -16.384000      -0.005069
# 1 -16.383875      -0.005069
# 2 -16.383750      -0.005069
# 3 -16.383625      -0.005069
# 4 -16.383500      -0.005069

# %%
x=data_df["Time (s)"]
y=data_df["Channel 1 (V)"]
plt.figure(figsize=(24, 20))
plt.ylim(-.1,.1)
plt.scatter(x,y)
plt.xlabel("t (s)")
plt.ylabel("v (m/s)")
# Out:
# Text(0, 0.5, 'v (m/s)')
